# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth5723/Daily_learning/blob/main/Advance_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#iterators
my_list = [1,2,3,4,5,6]
for i in range(len(my_list)):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
iterator = iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator=iter(my_list)

# %%
#iterator=iter(my_list)

try:
  print(next(iterator))
except StopIteration:
  print("there are no elements in the iterator left")
# Out:
# there are no elements in the iterator left

# %%
#Generators

def square(n):
  for i in range(3):
    yield i**2

# %%
square(2)
# Out:
# <generator object square at 0x7e85bd917370>

# %%
for i in square(3):
  print(i)
# Out:
# 0
# 1
# 4

# %%
a = square(3)
a
# Out:
# <generator object square at 0x7e85bd914ee0>

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_2679/1242322984.py in <cell line: 0>()
# ----> 1 next(a)
#
# StopIteration:

# %%
def my_generator():
  yield 1
  yield 2
  yield 3

# %%
gen = my_generator()
gen
# Out:
# <generator object my_generator at 0x7e85bdb0b480>

# %%
next(gen)
# Out:
# 1

# %%
for val in gen:
  print(val)
# Out:
# 2
# 3

# %%
## Practical : Reading Large Files
def read_large_files(file_path):
  with open(file_path , 'r') as file:
    for line in file:
      yield line

# %%
# function copy
# closures
# decoraters

#function copy
def welcome():
  return "Welcome"

welcome()
# Out:
# 'Welcome'

# %%
wel = welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome
# Welcome

# %%
## closures

def main_welcome(msg):
  #msg = "Welcome"
  def sub_welcome_method():
    print("welcome to my house")
    print(msg)
    print("please come in")
  return sub_welcome_method()

# %%
main_welcome("welcome")
# Out:
# welcome to my house
# welcome
# please come in

# %%
def main_welcome(func):

  def sub_welcome_method():
    print("welcome to my house")
    func()
    print("please come in")
  return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# welcome to my house
#
# please come in

# %%
def main_welcome(func, lst):
  def sub_welcome_method():
    print("welcome to my house")
    print(func(lst))
    print("please come in")
  return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# welcome to my house
# 5
# please come in

# %%
### Decorator

def main_welcome(func):

  def sub_welcome_method():
    print("welcome to my house")
    print(func())
    print("please come in")
  return sub_welcome_method()

# %%
def course_introduction():
  print("this is my advanced python notebook")

course_introduction()
# Out:
# this is my advanced python notebook

# %%
main_welcome(course_introduction)
# Out:
# welcome to my house
# this is my advanced python notebook
# None
# please come in

# %%
@main_welcome
def course_introduction():
  print("this is an advanced python course")
# Out:
# welcome to my house
# this is an advanced python course
# None
# please come in

# %%
def my_decorator(func):
  def wrapper():
    print("Something is happening before the function is called")
    func()
    print("Something is happening after the function is called.")
  return wrapper

# %%
@my_decorator
def say_hello():
  print("hello")

# %%
say_hello()
# Out:
# Something is happening before the function is called
# hello
# Something is happening after the function is called.

# %%
## Decorator with arguments
def repeat(n):
  def decorator(func):
    def wrapper(*args , **kwargs):
      for _ in range(n):
        func(*args, **kwargs)
    return wrapper
  return decorator

# %%
@repeat(3)
def say_hello():
  print("hello")

# %%
say_hello()
# Out:
# hello
# hello
# hello
