# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth5723/Daily_learning/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear Regression -- Single variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data  = {
    'area': [2600, 3000, 3200, 3600, 4000, 4200, 4500, 4800, 5000, 5500],
    'price': [550000, 565000, 610000, 680000, 725000, 750000, 790000, 825000, 860000, 940000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# 5  4200  750000
# 6  4500  790000
# 7  4800  825000
# 8  5000  860000
# 9  5500  940000

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area , df.price , color = "red" , marker ="+")
plt.show()
plt.tight_layout()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
print(reg.predict([[3300]]))
# Out:
# [627876.07269056]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area , df.price , color = "red" , marker ="+")
plt.plot(df.area , reg.predict(df[["area"]]) , color="blue")
plt.show()
plt.tight_layout()

# %%
d =  [[2800], [3300], [3500], [3800], [4100], [4400], [4700], [5200], [5600], [6000]]

df1 = pd.DataFrame(d)
print(df1)
# Out:
#       0
# 0  2800
# 1  3300
# 2  3500
# 3  3800
# 4  4100
# 5  4400
# 6  4700
# 7  5200
# 8  5600
# 9  6000

# %%
reg.predict(d)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([559211.25694094, 627876.07269056, 655341.99899041, 696540.88844018,
#        737739.77788995, 778938.66733973, 820137.5567895 , 888802.37253912,
#        943734.22513882, 998666.07773852])

# %%
#Linear regression -- Multiple variables

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
data_1 = {
    'area': [2600, 3000, 3200, 3600, 4000, 4100, 4500, 4800, 5100, 5500],
    'bedrooms': [3, 4, 3, None, 5, 6, 5, 4, 5, 6],
    'age': [20, 15, 18, 30, 8, 8, 12, 5, 2, 10],
    'price': [550000, 565000, 610000, 595000, 760000, 810000, 790000, 850000, 920000, 940000]
}

df_2 = pd.DataFrame(data_1)
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       NaN   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
#from sklearn.impute import SimpleImputer

# %%
#imputer = SimpleImputer(strategy = "median")


#df2['bedrooms'] = imputer.fit_transform(df2[['bedrooms']])

# %%
#print(df2.head(5))

# %%
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       NaN   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
import math
median_bedrooms = math.floor(df_2.bedrooms.median())
median_bedrooms
# Out:
# 5

# %%
df_2.bedrooms = df_2.bedrooms.fillna(median_bedrooms)
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       5.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
reg1 = linear_model.LinearRegression()
reg1.fit(df_2[['area' , 'bedrooms' , 'age']] , df_2.price)
# Out:
# LinearRegression()

# %%
reg1.predict([[3000 , 3 , 40]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([458104.92505353])

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot: Area, Age, and Price
ax.scatter(df_2['area'], df_2['age'], df_2['price'], c='purple', marker='o', s=100)

ax.set_xlabel('Area (sq ft)')
ax.set_ylabel('Age (Years)')
ax.set_zlabel('Price ($)')
ax.set_title('3D View: Area & Age vs Price')
plt.tight_layout()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

data= {
    'weight': np.random.randint(0,101,size = 20),
    'height': np.random.randint(0,201,size= 20)
}

df = pd.DataFrame(data)
print(df)
# Out:
#     weight  height
# 0       51     129
# 1       92     191
# 2       14     187
# 3       71      20
# 4       60     160
# 5       20      57
# 6       82      21
# 7       86      88
# 8       74      48
# 9       74      58
# 10      87     169
# 11      99     187
# 12      23      14
# 13       2     189
# 14      21     189
# 15      52     174
# 16       1     189
# 17      87      50
# 18      29     107
# 19      37      54

# %%
df.shape
# Out:
# (20, 2)

# %%
import matplotlib.pyplot as plt

# %%
if hasattr(plt, 'grid') and isinstance(plt.grid, bool):
  del plt.grid

import importlib
importlib.reload(plt)

plt.scatter(df['weight'] , df['height'] , alpha = 0.7)
plt.xlabel('weight')
plt.ylabel('height')
plt.title("weight and height correlation")

plt.grid(True , alpha = 0.7 , linestyle='--')

plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#           weight    height
# weight  1.000000 -0.201994
# height -0.201994  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.head()
# Out:
#    weight  height
# 0      51     129
# 1      92     191
# 2      14     187
# 3      71      20
# 4      60     160

# %%
x = df[['weight']]
y = df[['height']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25, random_state=42)

# %%
x_train.shape
# Out:
# (15, 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.17937229],
#        [ 0.92247932],
#        [-1.12098753],
#        [ 1.21440315],
#        [ 0.16347735]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression(n_jobs = -1)

# %%
regression.fit(x_train , y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("coefficient or slope:", regression.coef_)
print("Intercept:", regression.intercept_)
# Out:
# coefficient or slope: [[-16.16939715]]
# Intercept: [112.6]

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,regression.predict(x_train))

# %% [markdown]
# Prediction of Test Data.
# 1. predicted height output = intercept + coef_(weights)
#
# 2. y_pred_test = 156.470 + 17.29(x_test)

# %%
y_pred = regression.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 3520.656451437135
# 50.72418975056062
# 59.335119882217604

# %% [markdown]
# ## R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.02793705645828215

# %% [markdown]
# ## R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# -0.2960839247222904

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train,x_train).fit()

# %%
prediction = model.predict(x_test)
print(prediction)
# Out:
# [ 19.069739   -14.91593447  18.12569252 -19.63616689  -2.64333016]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                 height   R-squared (uncentered):                   0.015
# Model:                            OLS   Adj. R-squared (uncentered):             -0.055
# Method:                 Least Squares   F-statistic:                             0.2136
# Date:                Wed, 15 Jul 2026   Prob (F-statistic):                       0.651
# Time:                        13:10:37   Log-Likelihood:                         -94.403
# No. Observations:                  15   AIC:                                      190.8
# Df Residuals:                      14   BIC:                                      191.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
regression.predict(scaler.transform([[72]]))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[111.84476281]])

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import io

csv_data = """year,month,interest_rate,unemployment_rate,index_price
2024,January,3.25,3.6,4150.50
2024,February,3.25,3.6,4180.20
2024,March,3.50,3.5,4210.80
2024,April,3.50,3.5,4225.00
2024,May,3.75,3.5,4260.40
2024,June,3.75,3.4,4300.15
2024,July,4.00,3.4,4320.90
2024,August,4.00,3.4,4350.60
2024,September,4.25,3.5,4310.20
2024,October,4.25,3.5,4285.40
2024,November,4.50,3.6,4250.00
2024,December,4.50,3.6,4290.80
2025,January,4.75,3.7,4220.30
2025,February,4.75,3.7,4190.50
2025,March,5.00,3.8,4150.10
2025,April,5.00,3.8,4110.40
2025,May,5.25,3.9,4080.60
2025,June,5.25,4.0,4050.25
2025,July,5.25,4.1,4020.00
2025,August,5.25,4.2,3995.70
2025,September,5.00,4.3,4030.40
2025,October,5.00,4.4,4065.10
2025,November,4.75,4.5,4110.90
2025,December,4.75,4.5,4150.30
2026,January,4.50,4.6,4190.00
2026,February,4.50,4.6,4225.40
2026,March,4.25,4.7,4260.80
2026,April,4.25,4.7,4295.20
2026,May,4.00,4.6,4340.50
2026,June,4.00,4.5,4390.10"""


df = pd.read_csv(io.StringIO(csv_data))

df['date'] = df['month'] + ' ' + df['year'].astype(str)

print("--- Dataset  Sample ---")
print(df.describe())

fig, ax1 = plt.subplots(figsize = (12,6))

color = 'tab:blue'
ax1.set_xlabel('Timeline')
ax1.set_ylabel('Index Price', color=color)
ax1.plot(df['date'], df['index_price'], color=color, linewidth=2.5, label='Index Price')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(df['date'], rotation=45, ha='right')

ax2 = ax1.twinx()
color2 = 'tab:orange'
color3 = 'tab:green'
ax2.set_ylabel('Percentage (%)', color='black')
ax2.plot(df['date'], df['interest_rate'], color=color2, linestyle='--', linewidth=2, label='Interest Rate')
ax2.plot(df['date'], df['unemployment_rate'], color=color3, linestyle=':', linewidth=2, label='Unemployment Rate')
ax2.tick_params(axis='y', labelcolor='black')

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

plt.title('Economic Cycle Simulation: Interest Rates, Unemployment, & Market Index', fontsize=14, pad=15)
plt.tight_layout()
plt.show()
# Out:
# --- Dataset  Sample ---
#               year  interest_rate  unemployment_rate  index_price
# count    30.000000      30.000000          30.000000    30.000000
# mean   2024.800000       4.400000           3.956667  4200.383333
# std       0.761124       0.607425           0.465857   107.210928
# min    2024.000000       3.250000           3.400000  3995.700000
# 25%    2024.000000       4.000000           3.525000  4120.700000
# 50%    2025.000000       4.500000           3.800000  4215.550000
# 75%    2025.000000       4.937500           4.475000  4289.450000
# max    2026.000000       5.250000           4.700000  4390.100000
# /tmp/ipykernel_619/361617475.py:52: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df['date'], rotation=45, ha='right')
