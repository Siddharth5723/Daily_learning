# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth5723/Daily_learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Linear Regression -- Single variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data  = {
    'area': [2600, 3000, 3200, 3600, 4000, 4200, 4500, 4800, 5000, 5500],
    'price': [550000, 565000, 610000, 680000, 725000, 750000, 790000, 825000, 860000, 940000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# 5  4200  750000
# 6  4500  790000
# 7  4800  825000
# 8  5000  860000
# 9  5500  940000

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area , df.price , color = "red" , marker ="+")
plt.show()
plt.tight_layout()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["area"]], df.price)
# Out:
# LinearRegression()

# %%
print(reg.predict([[3300]]))
# Out:
# [627876.07269056]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area , df.price , color = "red" , marker ="+")
plt.plot(df.area , reg.predict(df[["area"]]) , color="blue")
plt.show()
plt.tight_layout()

# %%
d =  [[2800], [3300], [3500], [3800], [4100], [4400], [4700], [5200], [5600], [6000]]

df1 = pd.DataFrame(d)
print(df1)
# Out:
#       0
# 0  2800
# 1  3300
# 2  3500
# 3  3800
# 4  4100
# 5  4400
# 6  4700
# 7  5200
# 8  5600
# 9  6000

# %%
reg.predict(d)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([559211.25694094, 627876.07269056, 655341.99899041, 696540.88844018,
#        737739.77788995, 778938.66733973, 820137.5567895 , 888802.37253912,
#        943734.22513882, 998666.07773852])

# %%
#Linear regression -- Multiple variables

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
data_1 = {
    'area': [2600, 3000, 3200, 3600, 4000, 4100, 4500, 4800, 5100, 5500],
    'bedrooms': [3, 4, 3, None, 5, 6, 5, 4, 5, 6],
    'age': [20, 15, 18, 30, 8, 8, 12, 5, 2, 10],
    'price': [550000, 565000, 610000, 595000, 760000, 810000, 790000, 850000, 920000, 940000]
}

df_2 = pd.DataFrame(data_1)
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       NaN   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
#from sklearn.impute import SimpleImputer

# %%
#imputer = SimpleImputer(strategy = "median")


#df2['bedrooms'] = imputer.fit_transform(df2[['bedrooms']])

# %%
#print(df2.head(5))

# %%
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       NaN   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
import math
median_bedrooms = math.floor(df_2.bedrooms.median())
median_bedrooms
# Out:
# 5

# %%
df_2.bedrooms = df_2.bedrooms.fillna(median_bedrooms)
print(df_2)
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       5.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000
# 6  4500       5.0   12  790000
# 7  4800       4.0    5  850000
# 8  5100       5.0    2  920000
# 9  5500       6.0   10  940000

# %%
reg1 = linear_model.LinearRegression()
reg1.fit(df_2[['area' , 'bedrooms' , 'age']] , df_2.price)
# Out:
# LinearRegression()

# %%
reg1.predict([[3000 , 3 , 40]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([458104.92505353])

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot: Area, Age, and Price
ax.scatter(df_2['area'], df_2['age'], df_2['price'], c='purple', marker='o', s=100)

ax.set_xlabel('Area (sq ft)')
ax.set_ylabel('Age (Years)')
ax.set_zlabel('Price ($)')
ax.set_title('3D View: Area & Age vs Price')
plt.tight_layout()
plt.grid()
plt.show()

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

data= {
    'weight': np.random.randint(0,101,size = 20),
    'height': np.random.randint(0,201,size= 20)
}

df = pd.DataFrame(data)
print(df)
# Out:
#     weight  height
# 0       51     129
# 1       92     191
# 2       14     187
# 3       71      20
# 4       60     160
# 5       20      57
# 6       82      21
# 7       86      88
# 8       74      48
# 9       74      58
# 10      87     169
# 11      99     187
# 12      23      14
# 13       2     189
# 14      21     189
# 15      52     174
# 16       1     189
# 17      87      50
# 18      29     107
# 19      37      54

# %%
df.shape
# Out:
# (20, 2)

# %%
import matplotlib.pyplot as plt

# %%
if hasattr(plt, 'grid') and isinstance(plt.grid, bool):
  del plt.grid

import importlib
importlib.reload(plt)

plt.scatter(df['weight'] , df['height'] , alpha = 0.7)
plt.xlabel('weight')
plt.ylabel('height')
plt.title("weight and height correlation")

plt.grid(True , alpha = 0.7 , linestyle='--')

plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#           weight    height
# weight  1.000000 -0.201994
# height -0.201994  1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.head()
# Out:
#    weight  height
# 0      51     129
# 1      92     191
# 2      14     187
# 3      71      20
# 4      60     160

# %%
x = df[['weight']]
y = df[['height']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25, random_state=42)

# %%
x_train.shape
# Out:
# (15, 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.17937229],
#        [ 0.92247932],
#        [-1.12098753],
#        [ 1.21440315],
#        [ 0.16347735]])

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression(n_jobs = -1)

# %%
regression.fit(x_train , y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
print("coefficient or slope:", regression.coef_)
print("Intercept:", regression.intercept_)
# Out:
# coefficient or slope: [[-16.16939715]]
# Intercept: [112.6]

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,regression.predict(x_train))

# %% [markdown]
# Prediction of Test Data.
# 1. predicted height output = intercept + coef_(weights)
#
# 2. y_pred_test = 156.470 + 17.29(x_test)

# %%
y_pred = regression.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# 3520.656451437135
# 50.72418975056062
# 59.335119882217604

# %% [markdown]
# ## R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
from sklearn.metrics import r2_score

# %%
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.02793705645828215

# %% [markdown]
# ## R square
# Formula
#
# **R^2 = 1 - SSR/SST**
#
#
# R^2	=	coefficient of determination
# SSR	=	sum of squares of residuals
# SST	=	total sum of squares

# %%
#display adjusted R-squared
1 - (1-score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
# Out:
# -0.2960839247222904

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train,x_train).fit()

# %%
prediction = model.predict(x_test)
print(prediction)
# Out:
# [ 19.069739   -14.91593447  18.12569252 -19.63616689  -2.64333016]

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 height   R-squared (uncentered):                   0.015
# Model:                            OLS   Adj. R-squared (uncentered):             -0.055
# Method:                 Least Squares   F-statistic:                             0.2136
# Date:                Wed, 15 Jul 2026   Prob (F-statistic):                       0.651
# Time:                        13:10:37   Log-Likelihood:                         -94.403
# No. Observations:                  15   AIC:                                      190.8
# Df Residuals:                      14   BIC:                                      191.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           -16.1694     34.990     -0.462      0.651     -91.215      58.876
# ==============================================================================
# Omnibus:                        5.072   Durbin-Watson:                   0.616
# Prob(Omnibus):                  0.079   Jarque-Bera (JB):                1.432
# Skew:                          -0.130   Prob(JB):                        0.489
# Kurtosis:                       1.509   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
regression.predict(scaler.transform([[72]]))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[111.84476281]])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = 6 * np.random.rand(100, 1) - 3
y = 0.5 * x**2 + 1.5*x + 2 + np.random.randn(100, 1)
plt.scatter(x,y,color='r')
plt.xlabel("X dataset")
plt.ylabel("y label")
# Out:
# Text(0, 0.5, 'y label')

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
x_test
# Out:
# array([[-2.47051354],
#        [ 2.47369402],
#        [ 1.54066302],
#        [ 0.81953204],
#        [ 0.43035493],
#        [ 1.30377697],
#        [ 0.54628539],
#        [ 1.31243248],
#        [ 1.47557816],
#        [-1.4342913 ],
#        [ 2.18474006],
#        [-1.01623888],
#        [-2.07306051],
#        [-0.63281653],
#        [-0.16702812],
#        [ 2.89273109],
#        [-1.87397426],
#        [-1.29964784],
#        [ 2.78201455],
#        [-1.8440987 ]])

# %%
from sklearn.linear_model import LinearRegression
regression_1 = LinearRegression()

# %%
regression_1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, regression_1.predict(x_test))
print(score)
# Out:
# 0.7744765720054484

# %%
plt.plot(x_train,regression_1.predict(x_train), color='r')
plt.scatter(x_train,y_train)
plt.xlabel("x_dataset")
plt.ylabel("y dataset")
# Out:
# Text(0, 0.5, 'y dataset')

# %%
## applying polynomial transofrmation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=3,include_bias=True)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00, -3.98064246e-01,  1.58455144e-01,
#         -6.30753274e-02],
#        [ 1.00000000e+00, -2.15209387e+00,  4.63150804e+00,
#         -9.96744007e+00],
#        [ 1.00000000e+00,  6.87839084e-01,  4.73122606e-01,
#          3.25432220e-01],
#        [ 1.00000000e+00, -9.86948893e-01,  9.74068118e-01,
#         -9.61355451e-01],
#        [ 1.00000000e+00,  2.26893777e+00,  5.14807861e+00,
#          1.16806700e+01],
#        [ 1.00000000e+00, -2.55098090e+00,  6.50750356e+00,
#         -1.66005173e+01],
#        [ 1.00000000e+00, -2.77713587e+00,  7.71248364e+00,
#         -2.14186150e+01],
#        [ 1.00000000e+00, -2.25261146e+00,  5.07425841e+00,
#         -1.14303327e+01],
#        [ 1.00000000e+00,  7.15028714e-01,  5.11266062e-01,
#          3.65569915e-01],
#        [ 1.00000000e+00,  1.11865068e+00,  1.25137934e+00,
#          1.39985635e+00],
#        [ 1.00000000e+00,  2.64865921e+00,  7.01539560e+00,
#          1.85813921e+01],
#        [ 1.00000000e+00,  2.15534201e+00,  4.64549919e+00,
#          1.00126396e+01],
#        [ 1.00000000e+00,  1.92651141e+00,  3.71144623e+00,
#          7.15014351e+00],
#        [ 1.00000000e+00, -2.82642248e+00,  7.98866404e+00,
#         -2.25793396e+01],
#        [ 1.00000000e+00,  2.11934017e+00,  4.49160278e+00,
#          9.51923421e+00],
#        [ 1.00000000e+00,  8.90471271e-01,  7.92939085e-01,
#          7.06089474e-01],
#        [ 1.00000000e+00, -5.12091425e-01,  2.62237627e-01,
#         -1.34289640e-01],
#        [ 1.00000000e+00,  1.76373284e+00,  3.11075352e+00,
#          5.48653812e+00],
#        [ 1.00000000e+00, -1.12926025e+00,  1.27522870e+00,
#         -1.44006508e+00],
#        [ 1.00000000e+00,  1.30334951e+00,  1.69871994e+00,
#          2.21402579e+00],
#        [ 1.00000000e+00, -1.80984786e+00,  3.27554928e+00,
#         -5.92824585e+00],
#        [ 1.00000000e+00, -1.67823716e+00,  2.81647995e+00,
#         -4.72672131e+00],
#        [ 1.00000000e+00,  2.56375842e-01,  6.57285726e-02,
#          1.68512182e-02],
#        [ 1.00000000e+00,  1.52845649e+00,  2.33617925e+00,
#          3.57074834e+00],
#        [ 1.00000000e+00,  1.24570571e+00,  1.55178271e+00,
#          1.93306458e+00],
#        [ 1.00000000e+00,  2.70006486e+00,  7.29035024e+00,
#          1.96844185e+01],
#        [ 1.00000000e+00, -5.23322350e-01,  2.73866282e-01,
#         -1.43320346e-01],
#        [ 1.00000000e+00,  2.13155864e+00,  4.54354224e+00,
#          9.68482672e+00],
#        [ 1.00000000e+00,  2.01016150e+00,  4.04074927e+00,
#          8.12255861e+00],
#        [ 1.00000000e+00,  2.33289143e+00,  5.44238242e+00,
#          1.26964873e+01],
#        [ 1.00000000e+00, -1.86833065e+00,  3.49065943e+00,
#         -6.52170601e+00],
#        [ 1.00000000e+00, -1.50953752e+00,  2.27870353e+00,
#         -3.43978847e+00],
#        [ 1.00000000e+00,  8.05115545e-02,  6.48211040e-03,
#          5.21884784e-04],
#        [ 1.00000000e+00, -1.35017872e-01,  1.82298259e-02,
#         -2.46135231e-03],
#        [ 1.00000000e+00,  7.90895342e-01,  6.25515442e-01,
#          4.94717249e-01],
#        [ 1.00000000e+00, -2.02006216e+00,  4.08065113e+00,
#         -8.24316894e+00],
#        [ 1.00000000e+00, -1.85495313e+00,  3.44085112e+00,
#         -6.38261755e+00],
#        [ 1.00000000e+00,  1.74966147e+00,  3.06131527e+00,
#          5.35626537e+00],
#        [ 1.00000000e+00,  2.03069252e+00,  4.12371213e+00,
#          8.37399139e+00],
#        [ 1.00000000e+00, -1.39484905e+00,  1.94560388e+00,
#         -2.71382373e+00],
#        [ 1.00000000e+00,  2.17657661e+00,  4.73748574e+00,
#          1.03115006e+01],
#        [ 1.00000000e+00,  2.11322596e+00,  4.46572394e+00,
#          9.43708375e+00],
#        [ 1.00000000e+00,  2.00546933e+00,  4.02190724e+00,
#          8.06581162e+00],
#        [ 1.00000000e+00,  2.20915261e+00,  4.88035524e+00,
#          1.07814495e+01],
#        [ 1.00000000e+00, -2.73451150e+00,  7.47755313e+00,
#         -2.04474550e+01],
#        [ 1.00000000e+00,  5.38263359e-01,  2.89727444e-01,
#          1.55949667e-01]])

# %%
from sklearn.metrics import r2_score
regression = LinearRegression()
regression.fit(x_train_poly , y_train)
y_pred = regression.predict(x_test_poly)
score=r2_score(y_test, y_pred)
print(score)
# Out:
# 0.9295052098029238

# %%
print(regression.coef_)
# Out:
# [[0.         1.33360522 0.55711279 0.04595249]]

# %%
print(regression.intercept_)
# Out:
# [1.86363184]

# %%
plt.scatter(x_train,regression.predict(x_train_poly))
plt.scatter(x_train,y_train)

# %%
##Prediction of new dataset
x_new = np.linspace(-3,3,200).reshape(200, 1)
x_new_poly = poly.transform(x_new)
# x_new_poly

# %%
y_new = regression.predict(x_new_poly)
plt.plot(x_new,y_new,"r-",linewidth=2, label='Predictions')
plt.plot(x_train,y_train,"b.",label="training points")
plt.plot(x_test, y_test,"g.",label="Testing points")
plt.xlabel("x")
plt.ylabel('y')
plt.legend()
plt.show()
